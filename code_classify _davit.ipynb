# %%
import torch
import time
import os
import cv2
import random 
import torch.nn as nn
import numpy as np
import pandas as pd
import torch.backends.cudnn as cudnn
import torch.cuda.amp as amp 
import matplotlib.pyplot as plt
import seaborn as sns
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from pytorch_grad_cam import AblationCAM
from pytorch_grad_cam.ablation_layer import AblationLayerVit
from pytorch_grad_cam.utils.image import show_cam_on_image, preprocess_image
from torch.utils.data import DataLoader
from torch.optim.lr_scheduler import CosineAnnealingLR
from Davit.timm.models.davit import DaViT
from sklearn.metrics import accuracy_score, recall_score, f1_score, confusion_matrix
from torchsummary import summary
from sklearn.metrics import roc_curve, auc

# %% [markdown]
# ## Data Preprocessing & Augmentation
# - **rgb_to_lab_and_clahe function** - Performs conversion of RGB image to LAB color space after blurring (Gaussian) the Green (G) AND Blue (B) channels to emphasize the R channel and performs CLAHE.
# - **Augmentation** - Transforms like random Horizontal flip, Vertical flip, Rotation, Gaussian Blur, Affine, Perspective projection & MixUp are applied to create diversity in the training dataset to enhance model training and improve generalization.

# %%
def rgb_to_lab_and_clahe(img, clip_limit, tile_grid_size, blur_sigma):
    """
    Convert an RGB image to LAB color space, apply CLAHE (Contrast Limited Adaptive Histogram Equalization).

    Args:
        img (PIL.Image): Input RGB image.
        clip_limit (float): Clip limit for CLAHE.
        tile_grid_size (tuple): Size of the tile grid for CLAHE.
        blur_sigma (float): Standard deviation for Gaussian blur.

    Returns:
        lab_image (numpy.ndarray): LAB color space image.
    """        
    rgb_r, rgb_g, rgb_b = cv2.split(np.array(img))
    blurred_G = cv2.GaussianBlur(rgb_g, (5, 5), blur_sigma)
    blurred_B = cv2.GaussianBlur(rgb_b, (5, 5), blur_sigma)

    img = cv2.merge([rgb_r, blurred_G, blurred_B]) 
    lab_image = cv2.cvtColor(np.array(img), cv2.COLOR_RGB2Lab)
    L, a, b = cv2.split(lab_image)
    clahe = cv2.createCLAHE(clipLimit=clip_limit, tileGridSize=tile_grid_size)
    clahed_L = clahe.apply(L)  
    modified_lab_image = cv2.merge([clahed_L, a, b])
    rgb_image = cv2.cvtColor(modified_lab_image, cv2.COLOR_LAB2RGB)
    return lab_image 

train_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.RandomRotation(degrees=180), 
    transforms.GaussianBlur(kernel_size=5, sigma=(1.0, 3.0)),
    transforms.RandomAffine(degrees=0, translate=(0.25, 0.25), scale=(0.9, 1.1)),
    transforms.RandomPerspective(distortion_scale=0.5, p=0.5),
    lambda x: rgb_to_lab_and_clahe(x, clip_limit=5.0, tile_grid_size=(8, 8), blur_sigma=1.0),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.0, 0.0, 0.0), std=(1.0, 1.0, 1.0)),   
])

val_transform = transforms.Compose([
    lambda x: rgb_to_lab_and_clahe(x, clip_limit=5.0, tile_grid_size=(8, 8), blur_sigma=1.0),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.0, 0.0, 0.0), std=(1.0, 1.0, 1.0)),  
])

def mixup(data, targets, alpha=1.0):
    """
    Applies MixUp augmentation to the input data and targets.

    Args:
        data (torch.Tensor): Input data tensor.
        targets (torch.Tensor): Target labels tensor.
        alpha (float): MixUp hyperparameter controlling the mix ratio.

    Returns:
        mixed_data (torch.Tensor): Mixed data tensor.
        targets_a (torch.Tensor): Targets for the first data sample.
        targets_b (torch.Tensor): Targets for the second data sample.
        lam (float): Lambda value representing the mix ratio.
    """
    if alpha == 0:
        return data, targets, targets, 1.0 
    lam = np.random.beta(alpha, alpha)
    batch_size = data.size(0)
    index = torch.randperm(batch_size)
    mixed_data = lam * data + (1 - lam) * data[index, :]
    targets_a, targets_b = targets, targets[index]
    return mixed_data, targets_a, targets_b, lam

# %% [markdown]
# ## Data Loading

# %%
torch.cuda.is_available()
# Out:
# True

# %%
# Set the device for PyTorch to CUDA if available, otherwise use CPU.
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Set a random seed for reproducibility and configure CUDA for benchmarking.
seed = 2
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)
cudnn.benchmark = True

# Define the file paths for the training and validation datasets.
train_data_path = '/home/ee22s501/c2/data_classify/train'
val_data_path = '/home/ee22s501/c2/data_classify/val'

# Create PyTorch datasets with specified transformations.
train_dataset = ImageFolder(train_data_path, transform=train_transform)
val_dataset = ImageFolder(val_data_path, transform=val_transform)

# Set the batch size and create data loaders for training and validation.
batch_size = 8
train_loader = DataLoader(train_dataset, batch_size=batch_size,shuffle=True, num_workers=8)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=True, num_workers=8)

# %% [markdown]
# ## Model, Criterion & Optimizer

# %%
# Define the Swin Transformer model configuration.
davit_config = {
    'img_size': 224,
    'patch_size': 4,  # Tiny uses patch size 4
    'in_chans': 3,
    'num_classes': 2,
    'embed_dim': (96, 192, 384, 768),  # Tiny uses embed dimension 96 for all stages
    'depths': [1, 1, 3, 1],  # Tiny has specific number of blocks per stage
    'num_heads': [3, 6, 12, 24],  # Tiny has specific number of heads per stage
    'window_size': 7,  # Tiny uses window size 7
    'mlp_ratio': 4,  # Tiny uses mlp_ratio 4
    'qkv_bias': True,  # This can vary depending on implementation
    # Other parameters are set to defaults like in the original implementation
}


# Instantiate Swin Transformer model. 
model = DaViT(img_size=davit_config['img_size'],
                        patch_size=davit_config['patch_size'],
                        in_chans=davit_config['in_chans'],
                        num_classes=davit_config['num_classes'],
                        embed_dims=davit_config['embed_dim'],
                        depths=davit_config['depths'],
                        num_heads=davit_config['num_heads'],
                        window_size=davit_config['window_size'],
                        mlp_ratio=davit_config['mlp_ratio'],
                        qkv_bias=True,
                        #qk_scale=None,
                        #drop_rate=0.0,
                        drop_path_rate=0.1,
                      #ape=False,
                        #patch_norm=True,
                        #use_checkpoint=False,
                        #used_window_process=False
                        ).to(device)

# Generate a summary of the model's architecture
#summary(model, (3, 224, 224)) 

# Set up the Cross Entropy loss function
criterion = nn.CrossEntropyLoss()

# Set the Optimizer as AdamW
optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=7.8e-5,     
    betas=(0.9, 0.999), 
    eps=1.0e-012,      
    weight_decay=0.05,   
)

# Set the Scheduler
scheduler = CosineAnnealingLR(
    optimizer,
    T_max=30,   
    eta_min=7.8125e-08  
)

# Set gradient scaler
scaler = amp.GradScaler()

# %% [markdown]
# ## Training and Validation

# %%
# Initialize training parameters and lists to track metrics.
num_epochs = 100
best_accuracy = 0.0
best_recall = 0.0
best_f1_score = 0.0
best_epoch_accuracy = 0
best_model_path = '/home/ee22s501/cvip/code/DaViT_models_test_3'
train_losses = []
val_losses = []
val_accuracies = []
precision,recall_anil,specificity=[],[],[]


# Main training loop over epochs.
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    start_time = time.time()

    # Training loop over batches.
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)

        # Apply MixUp augmentation.
        if np.random.rand() < 0.5:
            images, targets_a, targets_b, lam = mixup(images, labels, alpha=1.0)
        else:
            images, targets_a, targets_b, lam = mixup(images, labels, alpha=1.0)
        optimizer.zero_grad()
        
        with amp.autocast():
            outputs = model(images)
            #loss = criterion(outputs, labels)
            
            loss = lam * criterion(outputs, targets_a) + (1 - lam) * criterion(outputs, targets_b)
            
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        #scheduler.step()

        running_loss += loss.item()
    
    train_losses.append(running_loss/len(train_loader))
    end_time = time.time()
    epoch_time = end_time - start_time
    print("############################################################")
    print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {running_loss/len(train_loader)}, Time: {epoch_time:.2f} seconds")

    if (epoch) % 1 == 0:
        model.eval()
        correct = 0
        total = 0
        TP=0
        FN=0
        val_predictions = []
        val_labels = []
        running_val_loss = 0.0

        # Validation loop to evaluate model performance.
        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
      
                outputs = model(images)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
                TP += sum(1 for x, y in zip(predicted, labels) if x == y == 1)
                FN += sum(1 for x, y in zip(predicted, labels) if x != y and  y==1)

                val_predictions.extend(predicted.cpu().numpy())
                val_labels.extend(labels.cpu().numpy())

                val_loss = criterion(outputs, labels)   
                running_val_loss += val_loss.item()
        TN=correct - TP
        FP=(total-correct) - FN
        eps = 1e-12
        val_precision= TP/(TP+FP+eps)
        precision.append(val_precision)
        val_recall=TP/(TP+FN+eps)
        recall_anil.append(val_recall)
        val_specificity=TN/(TN+FP+eps)
        specificity.append(val_specificity)

        accuracy = 100 * correct / total
        val_losses.append(running_val_loss/len(val_loader))

        # Print and save model performance metrics.
        print(f"Val Loss: {running_val_loss/len(val_loader)}")
        val_accuracies.append(accuracy)
        recall = recall_score(val_labels, val_predictions)
        f1 = f1_score(val_labels, val_predictions)

        print(f"Current Validation Accuracy: {accuracy}%")
        print(f"Current Validation Recall: {recall}")
        print(f"Current Validation F1 Score: {f1}")

        # Save the model.
        model_path = os.path.join(best_model_path, f"model_classify_{epoch}.pth")
        torch.save(model.state_dict(), model_path)
        print("Model Saved!")
# Plot training and validation metrics.
plt.figure(figsize=(12, 3))
plt.subplot(1, 3, 1)
plt.plot(range(1, num_epochs+1 , 1), train_losses, label='Train Loss', color='blue')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.gca().xaxis.set_major_locator(plt.MaxNLocator(integer=True))
plt.legend()

plt.subplot(1, 3, 2)
plt.plot(range(1, num_epochs +1, 1), val_losses, label='Validation Loss', color='orange')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.gca().xaxis.set_major_locator(plt.MaxNLocator(integer=True))
plt.legend()

plt.subplot(1, 3, 3)
plt.plot(range(1, num_epochs+1 , 1), val_accuracies, label='Validation Accuracy', color='green')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.gca().xaxis.set_major_locator(plt.MaxNLocator(integer=True))
plt.legend()
plt.show()

plt.figure(figsize=(12, 3))
plt.subplot(1, 2, 1)
plt.plot(specificity, recall_anil, label='TPR vs FPR', color='blue')
plt.xlabel('1-val_specificity   FPR')
plt.ylabel('TPR')
plt.legend()


plt.subplot(1, 2, 2)
plt.plot(recall_anil, precision, label='recall vs precision', color='green')
plt.xlabel('recall')
plt.ylabel('precision ')
plt.legend()
plt.show()
# Out:
# ############################################################
# Epoch 1/100, Train Loss: 0.7334302470429253, Time: 12.82 seconds
# Val Loss: 0.6869561103257266
# Current Validation Accuracy: 54.961832061068705%
# Current Validation Recall: 0.9961832061068703
# Current Validation F1 Score: 0.6886543535620053
# Model Saved!
# ############################################################
# Epoch 2/100, Train Loss: 0.6726826035794411, Time: 11.40 seconds
# Val Loss: 0.6373083446965073
# Current Validation Accuracy: 60.30534351145038%
# Current Validation Recall: 0.9961832061068703
# Current Validation F1 Score: 0.7150684931506849
# Model Saved!
# ############################################################
# Epoch 3/100, Train Loss: 0.633286704657642, Time: 11.47 seconds
# Val Loss: 0.6379269684354464
# Current Validation Accuracy: 60.68702290076336%
# Current Validation Recall: 0.9961832061068703
# Current Validation F1 Score: 0.717032967032967
# Model Saved!
# ############################################################
# Epoch 4/100, Train Loss: 0.6248375833717011, Time: 11.56 seconds
# Val Loss: 0.5338445427742872
# Current Validation Accuracy: 77.67175572519083%
# Current Validation Recall: 0.8435114503816794
# Current Validation F1 Score: 0.7906976744186046
# Model Saved!
# ############################################################
# Epoch 5/100, Train Loss: 0.5980551721144268, Time: 11.54 seconds
# Val Loss: 0.48164973836956604
# Current Validation Accuracy: 76.7175572519084%
# Current Validation Recall: 0.8129770992366412
# Current Validation F1 Score: 0.7773722627737226
# Model Saved!
# ############################################################
# Epoch 6/100, Train Loss: 0.5956550470290293, Time: 11.58 seconds
# Val Loss: 0.4461689212105491
# Current Validation Accuracy: 78.43511450381679%
# Current Validation Recall: 0.7442748091603053
# Current Validation F1 Score: 0.7753479125248509
# Model Saved!
# ############################################################
# Epoch 7/100, Train Loss: 0.5761266997979797, Time: 11.55 seconds
# Val Loss: 0.5296570712869818
# Current Validation Accuracy: 71.37404580152672%
# Current Validation Recall: 0.6335877862595419
# Current Validation F1 Score: 0.6887966804979253
# Model Saved!
# ############################################################
# Epoch 8/100, Train Loss: 0.5768681384679926, Time: 11.59 seconds
# Val Loss: 0.4038583223115314
# Current Validation Accuracy: 82.44274809160305%
# Current Validation Recall: 0.8320610687022901
# Current Validation F1 Score: 0.8257575757575758
# Model Saved!
# ############################################################
# Epoch 9/100, Train Loss: 0.5638562664958356, Time: 11.59 seconds
# Val Loss: 0.4452297387249542
# Current Validation Accuracy: 82.06106870229007%
# Current Validation Recall: 0.8740458015267175
# Current Validation F1 Score: 0.8297101449275363
# Model Saved!
# ############################################################
# Epoch 10/100, Train Loss: 0.5492803402643167, Time: 11.55 seconds
# Val Loss: 0.3859069159988201
# Current Validation Accuracy: 83.96946564885496%
# Current Validation Recall: 0.8931297709923665
# Current Validation F1 Score: 0.8478260869565217
# Model Saved!
# ############################################################
# Epoch 11/100, Train Loss: 0.5409124287143918, Time: 11.61 seconds
# Val Loss: 0.35727992495804123
# Current Validation Accuracy: 86.06870229007633%
# Current Validation Recall: 0.9389312977099237
# Current Validation F1 Score: 0.8707964601769912
# Model Saved!
# ############################################################
# Epoch 12/100, Train Loss: 0.5249812053018854, Time: 11.65 seconds
# Val Loss: 0.3624015206640417
# Current Validation Accuracy: 88.3587786259542%
# Current Validation Recall: 0.8740458015267175
# Current Validation F1 Score: 0.882466281310212
# Model Saved!
# ############################################################
# Epoch 13/100, Train Loss: 0.5225742336447913, Time: 11.64 seconds
# Val Loss: 0.3468778587200425
# Current Validation Accuracy: 84.35114503816794%
# Current Validation Recall: 0.9694656488549618
# Current Validation F1 Score: 0.8610169491525423
# Model Saved!
# ############################################################
# Epoch 14/100, Train Loss: 0.5085041698722439, Time: 11.64 seconds
# Val Loss: 0.3344578430282347
# Current Validation Accuracy: 87.59541984732824%
# Current Validation Recall: 0.8854961832061069
# Current Validation F1 Score: 0.8771266540642723
# Model Saved!
# ############################################################
# Epoch 15/100, Train Loss: 0.5053666074198621, Time: 11.68 seconds
# Val Loss: 0.3602365524028287
# Current Validation Accuracy: 84.16030534351145%
# Current Validation Recall: 0.9427480916030534
# Current Validation F1 Score: 0.8561525129982669
# Model Saved!
# ############################################################
# Epoch 16/100, Train Loss: 0.49474483671534153, Time: 11.62 seconds
# Val Loss: 0.32463071980711183
# Current Validation Accuracy: 89.12213740458016%
# Current Validation Recall: 0.8473282442748091
# Current Validation F1 Score: 0.8862275449101796
# Model Saved!
# ############################################################
# Epoch 17/100, Train Loss: 0.4793618146813553, Time: 11.63 seconds
# Val Loss: 0.29290370880202815
# Current Validation Accuracy: 86.6412213740458%
# Current Validation Recall: 0.950381679389313
# Current Validation F1 Score: 0.8767605633802817
# Model Saved!
# ############################################################
# Epoch 18/100, Train Loss: 0.5069144355659266, Time: 11.66 seconds
# Val Loss: 0.31477293462464306
# Current Validation Accuracy: 91.6030534351145%
# Current Validation Recall: 0.916030534351145
# Current Validation F1 Score: 0.916030534351145
# Model Saved!
# ############################################################
# Epoch 19/100, Train Loss: 0.48520432475186487, Time: 11.65 seconds
# Val Loss: 0.28051734535080014
# Current Validation Accuracy: 91.79389312977099%
# Current Validation Recall: 0.9122137404580153
# Current Validation F1 Score: 0.9174664107485605
# Model Saved!
# ############################################################
# Epoch 20/100, Train Loss: 0.48299787574596986, Time: 11.61 seconds
# Val Loss: 0.3121147592636672
# Current Validation Accuracy: 89.69465648854961%
# Current Validation Recall: 0.8282442748091603
# Current Validation F1 Score: 0.889344262295082
# Model Saved!
# ############################################################
# Epoch 21/100, Train Loss: 0.4872687715496726, Time: 11.62 seconds
# Val Loss: 0.29203760844062676
# Current Validation Accuracy: 91.03053435114504%
# Current Validation Recall: 0.9312977099236641
# Current Validation F1 Score: 0.9121495327102803
# Model Saved!
# ############################################################
# Epoch 22/100, Train Loss: 0.4826044311732736, Time: 11.67 seconds
# Val Loss: 0.3197297898657394
# Current Validation Accuracy: 87.78625954198473%
# Current Validation Recall: 0.7900763358778626
# Current Validation F1 Score: 0.8661087866108786
# Model Saved!
# ############################################################
# Epoch 23/100, Train Loss: 0.44963541251557476, Time: 11.73 seconds
# Val Loss: 0.360688655552539
# Current Validation Accuracy: 84.54198473282443%
# Current Validation Recall: 0.9389312977099237
# Current Validation F1 Score: 0.8586387434554974
# Model Saved!
# ############################################################
# Epoch 24/100, Train Loss: 0.468906065264276, Time: 11.73 seconds
# Val Loss: 0.2891096371141347
# Current Validation Accuracy: 91.98473282442748%
# Current Validation Recall: 0.9236641221374046
# Current Validation F1 Score: 0.9201520912547528
# Model Saved!
# ############################################################
# Epoch 25/100, Train Loss: 0.46696115728780513, Time: 11.76 seconds
# Val Loss: 0.2861750509702798
# Current Validation Accuracy: 91.6030534351145%
# Current Validation Recall: 0.8931297709923665
# Current Validation F1 Score: 0.9140625
# Model Saved!
# ############################################################
# Epoch 26/100, Train Loss: 0.4697062200831093, Time: 11.56 seconds
# Val Loss: 0.2737278960870974
# Current Validation Accuracy: 92.36641221374046%
# Current Validation Recall: 0.9427480916030534
# Current Validation F1 Score: 0.9250936329588015
# Model Saved!
# ############################################################
# Epoch 27/100, Train Loss: 0.46395130719961103, Time: 11.57 seconds
# Val Loss: 0.28179392692717636
# Current Validation Accuracy: 88.16793893129771%
# Current Validation Recall: 0.950381679389313
# Current Validation F1 Score: 0.8892857142857142
# Model Saved!
# ############################################################
# Epoch 28/100, Train Loss: 0.4768802812536254, Time: 11.57 seconds
# Val Loss: 0.2928371231890086
# Current Validation Accuracy: 90.26717557251908%
# Current Validation Recall: 0.950381679389313
# Current Validation F1 Score: 0.907103825136612
# Model Saved!
# ############################################################
# Epoch 29/100, Train Loss: 0.47103497101605396, Time: 11.58 seconds
# Val Loss: 0.29854427684437146
# Current Validation Accuracy: 93.3206106870229%
# Current Validation Recall: 0.9389312977099237
# Current Validation F1 Score: 0.9335863377609108
# Model Saved!
# ############################################################
# Epoch 30/100, Train Loss: 0.44927415445105723, Time: 11.58 seconds
# Val Loss: 0.4303467806541558
# Current Validation Accuracy: 83.20610687022901%
# Current Validation Recall: 0.7480916030534351
# Current Validation F1 Score: 0.8166666666666667
# Model Saved!
# ############################################################
# Epoch 31/100, Train Loss: 0.4535231250160523, Time: 11.60 seconds
# Val Loss: 0.3491435172882947
# Current Validation Accuracy: 90.64885496183206%
# Current Validation Recall: 0.8435114503816794
# Current Validation F1 Score: 0.90020366598778
# Model Saved!
# ############################################################
# Epoch 32/100, Train Loss: 0.45984616397901346, Time: 11.59 seconds
# Val Loss: 0.2660468704434055
# Current Validation Accuracy: 90.45801526717557%
# Current Validation Recall: 0.9656488549618321
# Current Validation F1 Score: 0.9100719424460432
# Model Saved!
# ############################################################
# Epoch 33/100, Train Loss: 0.4490584023581206, Time: 11.56 seconds
# Val Loss: 0.35025824572552333
# Current Validation Accuracy: 89.50381679389314%
# Current Validation Recall: 0.8320610687022901
# Current Validation F1 Score: 0.8879837067209776
# Model Saved!
# ############################################################
# Epoch 34/100, Train Loss: 0.44198883731515354, Time: 11.55 seconds
# Val Loss: 0.2759443618582957
# Current Validation Accuracy: 91.22137404580153%
# Current Validation Recall: 0.9580152671755725
# Current Validation F1 Score: 0.916058394160584
# Model Saved!
# ############################################################
# Epoch 35/100, Train Loss: 0.4571632393386983, Time: 11.56 seconds
# Val Loss: 0.26200125242273015
# Current Validation Accuracy: 91.6030534351145%
# Current Validation Recall: 0.9427480916030534
# Current Validation F1 Score: 0.9182156133828996
# Model Saved!
# ############################################################
# Epoch 36/100, Train Loss: 0.44915737498921293, Time: 11.55 seconds
# Val Loss: 0.37116501999623847
# Current Validation Accuracy: 83.58778625954199%
# Current Validation Recall: 0.7022900763358778
# Current Validation F1 Score: 0.8105726872246696
# Model Saved!
# ############################################################
# Epoch 37/100, Train Loss: 0.44532266023163575, Time: 11.60 seconds
# Val Loss: 0.31542938055865694
# Current Validation Accuracy: 90.26717557251908%
# Current Validation Recall: 0.8282442748091603
# Current Validation F1 Score: 0.8948453608247423
# Model Saved!
# ############################################################
# Epoch 38/100, Train Loss: 0.4417926925056763, Time: 11.60 seconds
# Val Loss: 0.2704270093730002
# Current Validation Accuracy: 91.03053435114504%
# Current Validation Recall: 0.9656488549618321
# Current Validation F1 Score: 0.9150090415913201
# Model Saved!
# ############################################################
# Epoch 39/100, Train Loss: 0.4433817695968479, Time: 11.60 seconds
# Val Loss: 0.24540443312038074
# Current Validation Accuracy: 93.70229007633588%
# Current Validation Recall: 0.9389312977099237
# Current Validation F1 Score: 0.9371428571428572
# Model Saved!
# ############################################################
# Epoch 40/100, Train Loss: 0.42338398880972206, Time: 11.55 seconds
# Val Loss: 0.24468933023286588
# Current Validation Accuracy: 91.6030534351145%
# Current Validation Recall: 0.9312977099236641
# Current Validation F1 Score: 0.9172932330827067
# Model Saved!
# ############################################################
# Epoch 41/100, Train Loss: 0.43975063589693025, Time: 11.57 seconds
# Val Loss: 0.3186401574674881
# Current Validation Accuracy: 88.93129770992367%
# Current Validation Recall: 0.8625954198473282
# Current Validation F1 Score: 0.8862745098039215
# Model Saved!
# ############################################################
# Epoch 42/100, Train Loss: 0.4421531476137292, Time: 11.54 seconds
# Val Loss: 0.20230073809172167
# Current Validation Accuracy: 95.22900763358778%
# Current Validation Recall: 0.9580152671755725
# Current Validation F1 Score: 0.952561669829222
# Model Saved!
# ############################################################
# Epoch 43/100, Train Loss: 0.4305006517026261, Time: 11.57 seconds
# Val Loss: 0.24497142467986455
# Current Validation Accuracy: 92.93893129770993%
# Current Validation Recall: 0.9045801526717557
# Current Validation F1 Score: 0.9275929549902152
# Model Saved!
# ############################################################
# Epoch 44/100, Train Loss: 0.4401592272724814, Time: 11.58 seconds
# Val Loss: 0.2619835023175586
# Current Validation Accuracy: 94.27480916030534%
# Current Validation Recall: 0.9274809160305344
# Current Validation F1 Score: 0.9418604651162791
# Model Saved!
# ############################################################
# Epoch 45/100, Train Loss: 0.42949093221366863, Time: 11.57 seconds
# Val Loss: 0.2236664296325409
# Current Validation Accuracy: 92.93893129770993%
# Current Validation Recall: 0.8816793893129771
# Current Validation F1 Score: 0.9258517034068137
# Model Saved!
# ############################################################
# Epoch 46/100, Train Loss: 0.42420323622476963, Time: 11.59 seconds
# Val Loss: 0.2402645820243792
# Current Validation Accuracy: 93.12977099236642%
# Current Validation Recall: 0.9122137404580153
# Current Validation F1 Score: 0.9299610894941635
# Model Saved!
# ############################################################
# Epoch 47/100, Train Loss: 0.43493065863620234, Time: 11.60 seconds
# Val Loss: 0.23579109787489427
# Current Validation Accuracy: 92.93893129770993%
# Current Validation Recall: 0.9694656488549618
# Current Validation F1 Score: 0.9321100917431193
# Model Saved!
# ############################################################
# Epoch 48/100, Train Loss: 0.43230934108372865, Time: 11.57 seconds
# Val Loss: 0.23418543126546976
# Current Validation Accuracy: 93.89312977099236%
# Current Validation Recall: 0.9694656488549618
# Current Validation F1 Score: 0.9407407407407408
# Model Saved!
# ############################################################
# Epoch 49/100, Train Loss: 0.44383664854325866, Time: 11.60 seconds
# Val Loss: 0.23137249639540008
# Current Validation Accuracy: 94.65648854961832%
# Current Validation Recall: 0.9236641221374046
# Current Validation F1 Score: 0.9453125
# Model Saved!
# ############################################################
# Epoch 50/100, Train Loss: 0.423119711796291, Time: 11.63 seconds
# Val Loss: 0.21903487701307645
# Current Validation Accuracy: 94.65648854961832%
# Current Validation Recall: 0.9312977099236641
# Current Validation F1 Score: 0.9457364341085271
# Model Saved!
# ############################################################
# Epoch 51/100, Train Loss: 0.4296173100708095, Time: 11.58 seconds
# Val Loss: 0.2115428846216563
# Current Validation Accuracy: 93.89312977099236%
# Current Validation Recall: 0.9809160305343512
# Current Validation F1 Score: 0.9413919413919414
# Model Saved!
# ############################################################
# Epoch 52/100, Train Loss: 0.4222092553120078, Time: 11.60 seconds
# Val Loss: 0.19491885653273625
# Current Validation Accuracy: 95.22900763358778%
# Current Validation Recall: 0.9694656488549618
# Current Validation F1 Score: 0.9530956848030019
# Model Saved!
# ############################################################
# Epoch 53/100, Train Loss: 0.4118309759229194, Time: 11.60 seconds
# Val Loss: 0.22674294911099202
# Current Validation Accuracy: 96.37404580152672%
# Current Validation Recall: 0.9732824427480916
# Current Validation F1 Score: 0.9640831758034026
# Model Saved!
# ############################################################
# Epoch 54/100, Train Loss: 0.42211702247043603, Time: 11.59 seconds
# Val Loss: 0.2181189591911706
# Current Validation Accuracy: 95.61068702290076%
# Current Validation Recall: 0.950381679389313
# Current Validation F1 Score: 0.9558541266794626
# Model Saved!
# ############################################################
# Epoch 55/100, Train Loss: 0.42039762221219884, Time: 11.59 seconds
# Val Loss: 0.25763470724676596
# Current Validation Accuracy: 92.17557251908397%
# Current Validation Recall: 0.8664122137404581
# Current Validation F1 Score: 0.9171717171717172
# Model Saved!
# ############################################################
# Epoch 56/100, Train Loss: 0.42342879918922904, Time: 11.57 seconds
# Val Loss: 0.22902330620722336
# Current Validation Accuracy: 95.0381679389313%
# Current Validation Recall: 0.9351145038167938
# Current Validation F1 Score: 0.9496124031007752
# Model Saved!
# ############################################################
# Epoch 57/100, Train Loss: 0.42006356180965443, Time: 11.57 seconds
# Val Loss: 0.17746404039137292
# Current Validation Accuracy: 96.56488549618321%
# Current Validation Recall: 0.9732824427480916
# Current Validation F1 Score: 0.9659090909090909
# Model Saved!
# ############################################################
# Epoch 58/100, Train Loss: 0.4243082057485599, Time: 11.59 seconds
# Val Loss: 0.22387866201725873
# Current Validation Accuracy: 94.46564885496183%
# Current Validation Recall: 0.9885496183206107
# Current Validation F1 Score: 0.946983546617916
# Model Saved!
# ############################################################
# Epoch 59/100, Train Loss: 0.4018348243570965, Time: 11.57 seconds
# Val Loss: 0.23139126485947406
# Current Validation Accuracy: 92.36641221374046%
# Current Validation Recall: 0.8816793893129771
# Current Validation F1 Score: 0.9203187250996016
# Model Saved!
# ############################################################
# Epoch 60/100, Train Loss: 0.420033298432827, Time: 11.60 seconds
# Val Loss: 0.20236854847859254
# Current Validation Accuracy: 94.8473282442748%
# Current Validation Recall: 0.916030534351145
# Current Validation F1 Score: 0.9467455621301775
# Model Saved!
# ############################################################
# Epoch 61/100, Train Loss: 0.4156071376197666, Time: 11.59 seconds
# Val Loss: 0.1819054110709465
# Current Validation Accuracy: 96.56488549618321%
# Current Validation Recall: 0.9847328244274809
# Current Validation F1 Score: 0.9662921348314607
# Model Saved!
# ############################################################
# Epoch 62/100, Train Loss: 0.42131357187874446, Time: 11.57 seconds
# Val Loss: 0.1966874518177726
# Current Validation Accuracy: 95.80152671755725%
# Current Validation Recall: 0.9389312977099237
# Current Validation F1 Score: 0.9571984435797666
# Model Saved!
# ############################################################
# Epoch 63/100, Train Loss: 0.41717397560941355, Time: 11.69 seconds
# Val Loss: 0.18026184104382992
# Current Validation Accuracy: 95.22900763358778%
# Current Validation Recall: 0.9580152671755725
# Current Validation F1 Score: 0.952561669829222
# Model Saved!
# ############################################################
# Epoch 64/100, Train Loss: 0.41260676048980416, Time: 11.61 seconds
# Val Loss: 0.18333439528942108
# Current Validation Accuracy: 96.94656488549619%
# Current Validation Recall: 0.9618320610687023
# Current Validation F1 Score: 0.9692307692307692
# Model Saved!
# ############################################################
# Epoch 65/100, Train Loss: 0.40539018878044975, Time: 11.56 seconds
# Val Loss: 0.20464375220013387
# Current Validation Accuracy: 95.80152671755725%
# Current Validation Recall: 0.9427480916030534
# Current Validation F1 Score: 0.9573643410852714
# Model Saved!
# ############################################################
# Epoch 66/100, Train Loss: 0.4104022002345278, Time: 11.57 seconds
# Val Loss: 0.20338487230015523
# Current Validation Accuracy: 97.32824427480917%
# Current Validation Recall: 0.9694656488549618
# Current Validation F1 Score: 0.9731800766283525
# Model Saved!
# ############################################################
# Epoch 67/100, Train Loss: 0.39039085469855606, Time: 11.56 seconds
# Val Loss: 0.23447102443738418
# Current Validation Accuracy: 93.3206106870229%
# Current Validation Recall: 0.8740458015267175
# Current Validation F1 Score: 0.9290060851926978
# Model Saved!
# ############################################################
# Epoch 68/100, Train Loss: 0.4330070229773303, Time: 11.57 seconds
# Val Loss: 0.21499418241508078
# Current Validation Accuracy: 93.89312977099236%
# Current Validation Recall: 0.9770992366412213
# Current Validation F1 Score: 0.9411764705882353
# Model Saved!
# ############################################################
# Epoch 69/100, Train Loss: 0.41064536233098453, Time: 11.61 seconds
# Val Loss: 0.1701286786207647
# Current Validation Accuracy: 96.18320610687023%
# Current Validation Recall: 0.9580152671755725
# Current Validation F1 Score: 0.9616858237547893
# Model Saved!
# ############################################################
# Epoch 70/100, Train Loss: 0.4057380727542038, Time: 11.56 seconds
# Val Loss: 0.24672384577041323
# Current Validation Accuracy: 92.36641221374046%
# Current Validation Recall: 0.8664122137404581
# Current Validation F1 Score: 0.9190283400809717
# Model Saved!
# ############################################################
# Epoch 71/100, Train Loss: 0.41235547927954724, Time: 11.62 seconds
# Val Loss: 0.2002814378250729
# Current Validation Accuracy: 95.80152671755725%
# Current Validation Recall: 0.9732824427480916
# Current Validation F1 Score: 0.9586466165413534
# Model Saved!
# ############################################################
# Epoch 72/100, Train Loss: 0.4048429748313573, Time: 11.55 seconds
# Val Loss: 0.2237144930457527
# Current Validation Accuracy: 94.08396946564885%
# Current Validation Recall: 0.9809160305343512
# Current Validation F1 Score: 0.9431192660550459
# Model Saved!
# ############################################################
# Epoch 73/100, Train Loss: 0.41580207139708614, Time: 11.57 seconds
# Val Loss: 0.18067175703066768
# Current Validation Accuracy: 94.8473282442748%
# Current Validation Recall: 0.916030534351145
# Current Validation F1 Score: 0.9467455621301775
# Model Saved!
# ############################################################
# Epoch 74/100, Train Loss: 0.40877859186352666, Time: 11.60 seconds
# Val Loss: 0.18832078497066643
# Current Validation Accuracy: 96.7557251908397%
# Current Validation Recall: 0.9770992366412213
# Current Validation F1 Score: 0.9678638941398866
# Model Saved!
# ############################################################
# Epoch 75/100, Train Loss: 0.39332421165215603, Time: 11.56 seconds
# Val Loss: 0.14187826724214989
# Current Validation Accuracy: 96.56488549618321%
# Current Validation Recall: 0.9465648854961832
# Current Validation F1 Score: 0.9649805447470817
# Model Saved!
# ############################################################
# Epoch 76/100, Train Loss: 0.4100338742990075, Time: 11.64 seconds
# Val Loss: 0.17121300360921657
# Current Validation Accuracy: 97.32824427480917%
# Current Validation Recall: 0.9694656488549618
# Current Validation F1 Score: 0.9731800766283525
# Model Saved!
# ############################################################
# Epoch 77/100, Train Loss: 0.4100740836037479, Time: 11.58 seconds
# Val Loss: 0.20085720909815846
# Current Validation Accuracy: 95.41984732824427%
# Current Validation Recall: 0.950381679389313
# Current Validation F1 Score: 0.9540229885057471
# Model Saved!
# ############################################################
# Epoch 78/100, Train Loss: 0.4042206034064293, Time: 11.56 seconds
# Val Loss: 0.14676829246860562
# Current Validation Accuracy: 96.7557251908397%
# Current Validation Recall: 0.9885496183206107
# Current Validation F1 Score: 0.9682242990654205
# Model Saved!
# ############################################################
# Epoch 79/100, Train Loss: 0.4019729469170552, Time: 11.58 seconds
# Val Loss: 0.16370182924649931
# Current Validation Accuracy: 97.32824427480917%
# Current Validation Recall: 0.9809160305343512
# Current Validation F1 Score: 0.9734848484848485
# Model Saved!
# ############################################################
# Epoch 80/100, Train Loss: 0.39732471173842443, Time: 11.59 seconds
# Val Loss: 0.22510800488067395
# Current Validation Accuracy: 93.12977099236642%
# Current Validation Recall: 0.8778625954198473
# Current Validation F1 Score: 0.9274193548387096
# Model Saved!
# ############################################################
# Epoch 81/100, Train Loss: 0.405404384468348, Time: 11.56 seconds
# Val Loss: 0.19848142987625164
# Current Validation Accuracy: 94.65648854961832%
# Current Validation Recall: 0.9961832061068703
# Current Validation F1 Score: 0.9490909090909091
# Model Saved!
# ############################################################
# Epoch 82/100, Train Loss: 0.4199645567031307, Time: 11.61 seconds
# Val Loss: 0.19731628093304057
# Current Validation Accuracy: 96.56488549618321%
# Current Validation Recall: 0.9618320610687023
# Current Validation F1 Score: 0.9655172413793104
# Model Saved!
# ############################################################
# Epoch 83/100, Train Loss: 0.39989353369438013, Time: 11.57 seconds
# Val Loss: 0.18887597807880604
# Current Validation Accuracy: 96.7557251908397%
# Current Validation Recall: 0.9541984732824428
# Current Validation F1 Score: 0.9671179883945842
# Model Saved!
# ############################################################
# Epoch 84/100, Train Loss: 0.3779858400092553, Time: 11.57 seconds
# Val Loss: 0.13397522219880062
# Current Validation Accuracy: 95.99236641221374%
# Current Validation Recall: 0.9923664122137404
# Current Validation F1 Score: 0.9611829944547134
# Model Saved!
# ############################################################
# Epoch 85/100, Train Loss: 0.4027551108018588, Time: 11.58 seconds
# Val Loss: 0.21133895291749275
# Current Validation Accuracy: 93.12977099236642%
# Current Validation Recall: 0.9961832061068703
# Current Validation F1 Score: 0.9354838709677419
# Model Saved!
# ############################################################
# Epoch 86/100, Train Loss: 0.40266124230190997, Time: 11.59 seconds
# Val Loss: 0.16298479293331955
# Current Validation Accuracy: 96.37404580152672%
# Current Validation Recall: 0.9465648854961832
# Current Validation F1 Score: 0.9631067961165048
# Model Saved!
# ############################################################
# Epoch 87/100, Train Loss: 0.37432071196896427, Time: 11.57 seconds
# Val Loss: 0.13866832259703765
# Current Validation Accuracy: 97.70992366412214%
# Current Validation Recall: 0.9618320610687023
# Current Validation F1 Score: 0.9767441860465116
# Model Saved!
# ############################################################
# Epoch 88/100, Train Loss: 0.40616198054706776, Time: 11.56 seconds
# Val Loss: 0.16775424439798703
# Current Validation Accuracy: 96.94656488549619%
# Current Validation Recall: 0.9541984732824428
# Current Validation F1 Score: 0.9689922480620154
# Model Saved!
# ############################################################
# Epoch 89/100, Train Loss: 0.4107641864368934, Time: 11.62 seconds
# Val Loss: 0.20542688786306165
# Current Validation Accuracy: 94.65648854961832%
# Current Validation Recall: 0.9656488549618321
# Current Validation F1 Score: 0.947565543071161
# Model Saved!
# ############################################################
# Epoch 90/100, Train Loss: 0.38847373097509375, Time: 11.60 seconds
# Val Loss: 0.15141676287307884
# Current Validation Accuracy: 96.18320610687023%
# Current Validation Recall: 0.9541984732824428
# Current Validation F1 Score: 0.9615384615384616
# Model Saved!
# ############################################################
# Epoch 91/100, Train Loss: 0.3796348900797258, Time: 11.59 seconds
# Val Loss: 0.22147279368205505
# Current Validation Accuracy: 94.27480916030534%
# Current Validation Recall: 0.9045801526717557
# Current Validation F1 Score: 0.9404761904761905
# Model Saved!
# ############################################################
# Epoch 92/100, Train Loss: 0.3911433815956116, Time: 11.56 seconds
# Val Loss: 0.1849946886526816
# Current Validation Accuracy: 95.41984732824427%
# Current Validation Recall: 0.9312977099236641
# Current Validation F1 Score: 0.953125
# Model Saved!
# ############################################################
# Epoch 93/100, Train Loss: 0.39113785644978966, Time: 11.58 seconds
# Val Loss: 0.1542019700687943
# Current Validation Accuracy: 96.18320610687023%
# Current Validation Recall: 0.9732824427480916
# Current Validation F1 Score: 0.9622641509433962
# Model Saved!
# ############################################################
# Epoch 94/100, Train Loss: 0.37600198521755124, Time: 11.58 seconds
# Val Loss: 0.16810801376899084
# Current Validation Accuracy: 96.18320610687023%
# Current Validation Recall: 0.9770992366412213
# Current Validation F1 Score: 0.9624060150375939
# Model Saved!
# ############################################################
# Epoch 95/100, Train Loss: 0.38389566552093013, Time: 11.55 seconds
# Val Loss: 0.16871888574325677
# Current Validation Accuracy: 94.27480916030534%
# Current Validation Recall: 0.9923664122137404
# Current Validation F1 Score: 0.9454545454545454
# Model Saved!
# ############################################################
# Epoch 96/100, Train Loss: 0.396711126979412, Time: 11.58 seconds
# Val Loss: 0.18957259664029785
# Current Validation Accuracy: 96.56488549618321%
# Current Validation Recall: 0.9427480916030534
# Current Validation F1 Score: 0.96484375
# Model Saved!
# ############################################################
# Epoch 97/100, Train Loss: 0.39577787383708335, Time: 11.53 seconds
# Val Loss: 0.184191082180901
# Current Validation Accuracy: 95.80152671755725%
# Current Validation Recall: 0.9809160305343512
# Current Validation F1 Score: 0.9589552238805971
# Model Saved!
# ############################################################
# Epoch 98/100, Train Loss: 0.39892615144716875, Time: 11.59 seconds
# Val Loss: 0.17880152267488567
# Current Validation Accuracy: 95.80152671755725%
# Current Validation Recall: 0.9351145038167938
# Current Validation F1 Score: 0.95703125
# Model Saved!
# ############################################################
# Epoch 99/100, Train Loss: 0.4047790494754569, Time: 11.57 seconds
# Val Loss: 0.17680281744987675
# Current Validation Accuracy: 96.7557251908397%
# Current Validation Recall: 0.9656488549618321
# Current Validation F1 Score: 0.9674952198852772
# Model Saved!
# ############################################################
# Epoch 100/100, Train Loss: 0.3747633452321054, Time: 11.60 seconds
# Val Loss: 0.19752714997439674
# Current Validation Accuracy: 93.70229007633588%
# Current Validation Recall: 1.0
# Current Validation F1 Score: 0.940754039497307
# Model Saved!

# %%
with torch.no_grad():
    for images, labels in val_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)

predicted = predicted.cpu()  # Move predicted tensor to CPU
x = np.array(predicted) 
labels = labels.cpu()  # Move predicted tensor to CPU
y = np.array(labels) 
fpr, tpr, _ = roc_curve(y,x)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ## Preprocessing & Dataloader for Test Data

# %%
#Defining data preprocessing for test data.
test_transform = transforms.Compose([
    lambda x: rgb_to_lab_and_clahe(x, clip_limit=5.0, tile_grid_size=(8, 8), blur_sigma=1.0),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.0, 0.0, 0.0), std=(1.0, 1.0, 1.0)),
])

#Defining path for saving test prediction, model checkpoint, CAMs, and Excel file
test_data_path =  '/home/ee22s501/cvip/code/dummy'
model_path = '/home/ee22s501/cvip/code/DaViT_models_test_3/model_classify_90.pth'
cams_path = '/home/ee22s501/cvip/code/DaViTresults/'
excel_file_path = '/home/ee22s501/cvip/code/DaViTresults/predictions.xlsx'
batch_size = 1

# Create a test dataset and data loader for inference.
test_dataset = ImageFolder(test_data_path, transform=test_transform)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=8)

# %% [markdown]
# ## Prediction and CAM plot generation

# %%
# Define a function to reshape a tensor for Ablation-CAM function 
def reshape_transform(tensor, height=7, width=7):
    """
    Reshape a tensor to the specified height and width dimensions.

    Args:
        tensor (torch.Tensor): Input tensor.
        height (int): Target height dimension.
        width (int): Target width dimension.

    Returns:
        result (torch.Tensor): Reshaped tensor.
    """
    result = tensor.reshape(tensor.size(0), height, width, tensor.size(2))
    result = result.transpose(2, 3).transpose(1, 2)
    return result 


# Load a pre-trained model and set it to evaluation mode.
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model.load_state_dict(torch.load(model_path))
model.eval()

# Define class names, fonts, and variables for predictions and image file names.
class_names = ['bleeding', 'non_bleeding']
i = 0
font = cv2.FONT_HERSHEY_SIMPLEX
font_scale = 0.5
font_color = (255, 255, 255)
font_thickness = 1
predicted_labels = []
image_file_names = []

# Loop through test data and generate predictions.
for images, _ in test_loader:
    images = images.to(device)
    outputs = model(images)
    _, predicted = torch.max(outputs.data, 1)
    predicted_label = class_names[predicted.item()]

    file_name = os.path.splitext(os.path.basename(test_loader.dataset.samples[i][0]))[0]
    image_file_names.append(file_name)
    predicted_labels.append(predicted.item())
    i += 1  
'''
# Uncomment this code for generating Ablation-CAM plots. 
    target_layers = [model.layers[-1].blocks[-1].norm2]
    cam = AblationCAM(model=model, target_layers=target_layers, reshape_transform=reshape_transform, ablation_layer=AblationLayerVit())
    grayscale_cam = cam(input_tensor=images, aug_smooth=True, eigen_smooth=True, targets=None)
    rgb_img = cv2.imread(test_loader.dataset.samples[i][0], 1)[:, :, ::-1]
    rgb_img_n = np.float32(rgb_img) / 255
    cam_image = show_cam_on_image(rgb_img_n, grayscale_cam[0, :])

    predicted_labels.append(predicted_label)
    image_file_names.append(os.path.basename(test_loader.dataset.samples[i][0]))

    combined_image = np.copy(cam_image)
    text = f'Predicted: {predicted_label}'
    cv2.putText(combined_image, text, (15, 15), font, font_scale, font_color, font_thickness)
    cv2.imwrite(os.path.join(cams_path, os.path.basename(test_loader.dataset.samples[i][0])), combined_image) 

    ## Append predicted labels and image file names.
    file_name = os.path.splitext(os.path.basename(test_loader.dataset.samples[i][0]))[0]
    image_file_names.append(file_name)
    predicted_labels.append(predicted.item())
    i += 1  '''

# Create a DataFrame and save predictions to an Excel file.
data = {
    'Image name': image_file_names,
    'Predicted Class label': predicted_labels,
}
df = pd.DataFrame(data)
df['Predicted Class label'] = df['Predicted Class label'].map({0: 'Bleeding', 1: 'Non-Bleeding'})

df.to_excel(excel_file_path, index=False)
print(f"Predictions saved to {excel_file_path}")
# Out:
# Predictions saved to /home/ee22s501/cvip/code/DaViTresults/predictions.xlsx
